# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# %%
X = np.array([
    [1, 2], [2, 3], [3, 3],
    [6, 5], [7, 7], [8, 6]
])
y = np.array([0, 0, 0, 1, 1, 1])

# %%
model = svm.SVC(kernel='rbf', C=1.0, gamma='scale')

# %%
model.fit(X, y)
# Out:
# SVC()

# %%
print("Support Vectors:\n", model.support_vectors_)
# Out:
# Support Vectors:
#  [[1. 2.]
#  [3. 3.]
#  [6. 5.]
#  [7. 7.]
#  [8. 6.]]

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', s=50)

# %%
plt.scatter(model.support_vectors_[:, 0],
            model.support_vectors_[:, 1],
            s=100, facecolors='none', edgecolors='k',
            label='Support Vectors')

# %%
xx, yy = np.meshgrid(np.linspace(0, 10, 100),
                     np.linspace(0, 10, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.2)
plt.title("Sparse Kernel Machine (SVM)")
plt.legend()
plt.grid()

plt.show()
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_20404\3818765422.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
